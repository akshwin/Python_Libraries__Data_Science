# %% [markdown]
# PANDAS

# %% [markdown]
# SERIES 1

# %%
import pandas as pd
import numpy as np

# %%
pd.Series?

# %%
pd.DataFrame?

# %%
my_pets = ['lion','cat','birds','fish']
my_pets
# Out:
# ['lion', 'cat', 'birds', 'fish']

# %%
pd.Series(my_pets) # convert list to series with indexes
# Out:
# 0     lion
# 1      cat
# 2    birds
# 3     fish
# dtype: object

# %% [markdown]
# CREATING OWN INDEX

# %%
my_days = ['Monday','Tuesday','Wednesday','Thursday','Friday']
my_course =['Economics','Geograpphy','Finance','Mathematics','History']

# %%
pd.Series(my_course)
# Out:
# 0      Economics
# 1     Geograpphy
# 2        Finance
# 3    Mathematics
# 4        History
# dtype: object

# %%
pd.Series(my_course,index = my_days)
# Out:
# Monday         Economics
# Tuesday       Geograpphy
# Wednesday        Finance
# Thursday     Mathematics
# Friday           History
# dtype: object

# %%
my_days1 = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']

# %%
pd.Series(my_course,index =my_days1) # length is different
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3d18a06dbfb7> in <cell line: 1>()
# ----> 1 pd.Series(my_course,index =my_days1) # length is different
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     459                 index = default_index(len(data))
#     460             elif is_list_like(data):
# --> 461                 com.require_length_match(data, index)
#     462
#     463             # create/copy the manager
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     569     """
#     570     if len(data) != len(index):
# --> 571         raise ValueError(
#     572             "Length of values "
#     573             f"({len(data)}) "
#
# ValueError: Length of values (5) does not match length of index (6)

# %%
days =pd.Series(['Monday','Tuesday','Wenesday','Thursday','Friday'],index=['Day1','Day2','Day3','Day4','Day5'])

# %%
days
# Out:
# Day1      Monday
# Day2     Tuesday
# Day3    Wenesday
# Day4    Thursday
# Day5      Friday
# dtype: object

# %% [markdown]
# SERIES 2

# %%
courses = pd.Series(['Economics','Geography','Finance','Mathematics','History'],index ='Day1 Day2 Day3 Day4 Day5'.split())
courses
# Out:
# Day1      Economics
# Day2      Geography
# Day3        Finance
# Day4    Mathematics
# Day5        History
# dtype: object

# %%
days + ' ' + courses # addition(concatenation) based on index
# Out:
# Day1        Monday Economics
# Day2       Tuesday Geography
# Day3        Wenesday Finance
# Day4    Thursday Mathematics
# Day5          Friday History
# dtype: object

# %%
courses
# Out:
# Day1      Economics
# Day2      Geography
# Day3        Finance
# Day4    Mathematics
# Day5        History
# dtype: object

# %%
courses['Day5']
# Out:
# 'History'

# %%
courses['Day2']
# Out:
# 'Geography'

# %%
courses[0]
# Out:
# 'Economics'

# %% [markdown]
# loc & iloc

# %%
# loc gets rows(columns) with a particular labels(name) from the index

# %%
# iloc gets rows(columns) at a particular positions in the index and it takes integers

# %%
sports = {'Football':'Spain',
          'NBA':'USA',
          'Cricket':'India',
          'Athletes':'Jamica'}

sports_series = pd.Series(sports)
sports_series
# Out:
# Football     Spain
# NBA            USA
# Cricket      India
# Athletes    Jamica
# dtype: object

# %%
sports_series.loc['Cricket']
# Out:
# 'India'

# %%
sports_series[1]
# Out:
# 'USA'

# %% [markdown]
# DATA FRAME INTRODUCTION

# %%
# Set of series is called data frame
# It contains set of rows and columns with index
# The datas are called data points.

# %% [markdown]
# OPERATIONS ON DATA FRAME

# %%
np.random.randn(10,5)#10x5
# Out:
# array([[-0.86274596,  1.02162237, -0.32200776, -0.07831404, -0.560305  ],
#        [ 1.04928806, -0.54185811, -0.82720196, -2.12855241,  0.11983062],
#        [ 0.42468232, -0.27495251, -0.42595144,  1.08446681, -0.4134584 ],
#        [ 0.90128866,  0.4653313 , -2.3099059 , -1.44610587, -1.20170441],
#        [-0.38091396, -0.23778438,  0.02568945, -0.77923015, -2.04961203],
#        [-1.10111144,  0.26255128,  0.5286207 , -1.03232153, -0.85714818],
#        [ 0.80246049, -1.56483578, -1.85996511, -1.99824966, -0.97959671],
#        [ 0.34876544, -1.14856345, -0.11329655,  0.41655577, -0.46560816],
#        [-1.06170146, -0.02641415,  1.28317157, -0.91971287, -0.63617026],
#        [ 0.3616493 , -0.86879455,  0.84357076, -1.00026514,  0.61083663]])

# %%
my_dataframe = pd.DataFrame(np.random.randn(10,5),index='row1 row2 row3 row4 row5 row6 row7 row8 row9 row10'.split(),columns='column1 column2 column3 column4 column5'.split())

# %%
my_dataframe
# Out:
#         column1   column2   column3   column4   column5
# row1   0.584527  1.426794 -0.229540 -1.608589  0.467805
# row2  -1.102857 -0.954725  0.626251  0.107779 -0.458245
# row3   1.994269 -1.934466  0.612049  1.459568 -1.916059
# row4   1.106287 -0.586124  0.998881  0.862140 -1.735787
# row5   0.415147  0.152710  0.149481  0.148058 -0.506599
# row6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665
# row7   0.011269 -0.483801 -1.129110  0.284472  0.095777
# row8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841
# row9  -0.165580  0.068137 -0.367314  0.304182  1.241040
# row10  0.011948 -0.115869 -0.171302  1.712098  0.301130

# %%
type(my_dataframe['column1'])
# Out:
# pandas.core.series.Series

# %%
type(my_dataframe)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# SELECTION AND INDEXING ON DATA FRAME

# %%
my_dataframe['column2']
# Out:
# row1     1.426794
# row2    -0.954725
# row3    -1.934466
# row4    -0.586124
# row5     0.152710
# row6    -0.028043
# row7    -0.483801
# row8     0.427747
# row9     0.068137
# row10   -0.115869
# Name: column2, dtype: float64

# %%
my_dataframe[['column1','column2','column3']]
# Out:
#         column1   column2   column3
# row1   0.584527  1.426794 -0.229540
# row2  -1.102857 -0.954725  0.626251
# row3   1.994269 -1.934466  0.612049
# row4   1.106287 -0.586124  0.998881
# row5   0.415147  0.152710  0.149481
# row6  -0.147053 -0.028043  0.341747
# row7   0.011269 -0.483801 -1.129110
# row8  -0.137943  0.427747 -1.297815
# row9  -0.165580  0.068137 -0.367314
# row10  0.011948 -0.115869 -0.171302

# %% [markdown]
# READING A DATASET WITH PANDAS

# %%
#cat Automobile.csv

# %%
data = pd.read_csv('Automobile.csv')
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data.head(15)
# Out:
#     symboling  normalized_losses         make fuel_type aspiration  \
# 0           3                168  alfa-romero       gas        std
# 1           3                168  alfa-romero       gas        std
# 2           1                168  alfa-romero       gas        std
# 3           2                164         audi       gas        std
# 4           2                164         audi       gas        std
# 5           2                161         audi       gas        std
# 6           1                158         audi       gas        std
# 7           1                168         audi       gas        std
# 8           1                158         audi       gas      turbo
# 9           2                192          bmw       gas        std
# 10          0                192          bmw       gas        std
# 11          0                188          bmw       gas        std
# 12          0                188          bmw       gas        std
# ...

# %%
data.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
data.tail(10)
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# ...

# %% [markdown]
# ADDING COLUMN TO A PANDAS DATA FRAME

# %%
my_dataframe
# Out:
#          first    second     third   column4    fourth   column6
# spin
# sp1   0.584527  1.426794 -0.229540 -1.608589  0.467805  1.169055
# sp2  -1.102857 -0.954725  0.626251  0.107779 -0.458245 -2.205715
# sp3   1.994269 -1.934466  0.612049  1.459568 -1.916059  3.988538
# sp4   1.106287 -0.586124  0.998881  0.862140 -1.735787  2.212574
# sp5   0.415147  0.152710  0.149481  0.148058 -0.506599  0.830293
# sp6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665 -0.294106
# sp7   0.011269 -0.483801 -1.129110  0.284472  0.095777  0.022539
# sp8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841 -0.275886
# sp9  -0.165580  0.068137 -0.367314  0.304182  1.241040 -0.331160

# %%
my_dataframe['column6'] = my_dataframe['column1']*2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
my_dataframe
# Out:
#          first    second     third   column4    fourth   column6
# spin
# sp1   0.584527  1.426794 -0.229540 -1.608589  0.467805  1.169055
# sp2  -1.102857 -0.954725  0.626251  0.107779 -0.458245 -2.205715
# sp3   1.994269 -1.934466  0.612049  1.459568 -1.916059  3.988538
# sp4   1.106287 -0.586124  0.998881  0.862140 -1.735787  2.212574
# sp5   0.415147  0.152710  0.149481  0.148058 -0.506599  0.830293
# sp6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665 -0.294106
# sp7   0.011269 -0.483801 -1.129110  0.284472  0.095777  0.022539
# sp8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841 -0.275886
# sp9  -0.165580  0.068137 -0.367314  0.304182  1.241040 -0.331160

# %%
type(my_dataframe['column6'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# DROP COLUMNS AND ROWS IN PANDAS

# %%
my_dataframe.drop('columns',axis=1) # axis = 1 for columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-9bdf6dbc7df1> in <cell line: 1>()
# ----> 1 my_dataframe.drop('columns',axis=1) # axis = 1 for columns
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
my_dataframe.drop('row10',axis=0) # axis = 0 for rows

# %%
my_dataframe

# %%
my_dataframe.drop('columns',axis = 1,inplace = True) # modifies the original data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-eaebcea381b9> in <cell line: 1>()
# ----> 1 my_dataframe.drop('columns',axis = 1,inplace = True) # modifies the original data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
my_dataframe

# %%
my_dataframe.drop('row10',axis=0,inplace=True)

# %%
my_dataframe

# %%
my_dataframe.iloc[1]
# Out:
# first     -1.102857
# second    -0.954725
# third      0.626251
# column4    0.107779
# fourth    -0.458245
# column6   -2.205715
# Name: sp2, dtype: float64

# %%
my_dataframe.iloc[0,0]
# Out:
# 0.5845274687477402

# %%
my_dataframe.loc['row2']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'row2'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
my_dataframe.loc['row2','column1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# RESET INDEX IN PANDAS DATA FRAME

# %%
my_dataframe

# %%
my_dataframe.index
# Out:
# Index(['sp1', 'sp2', 'sp3', 'sp4', 'sp5', 'sp6', 'sp7', 'sp8', 'sp9'], dtype='object', name='spin')

# %%
my_dataframe['spin']= ['sp1','sp2','sp3','sp4','sp5','sp6','sp7','sp8','sp9']

# %%
my_dataframe
# Out:
#          first    second     third   column4    fourth   column6 spin
# spin
# sp1   0.584527  1.426794 -0.229540 -1.608589  0.467805  1.169055  sp1
# sp2  -1.102857 -0.954725  0.626251  0.107779 -0.458245 -2.205715  sp2
# sp3   1.994269 -1.934466  0.612049  1.459568 -1.916059  3.988538  sp3
# sp4   1.106287 -0.586124  0.998881  0.862140 -1.735787  2.212574  sp4
# sp5   0.415147  0.152710  0.149481  0.148058 -0.506599  0.830293  sp5
# sp6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665 -0.294106  sp6
# sp7   0.011269 -0.483801 -1.129110  0.284472  0.095777  0.022539  sp7
# sp8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841 -0.275886  sp8
# sp9  -0.165580  0.068137 -0.367314  0.304182  1.241040 -0.331160  sp9

# %%
my_dataframe.set_index('spin',inplace=True)

# %%
my_dataframe
# Out:
#          first    second     third   column4    fourth   column6
# spin
# sp1   0.584527  1.426794 -0.229540 -1.608589  0.467805  1.169055
# sp2  -1.102857 -0.954725  0.626251  0.107779 -0.458245 -2.205715
# sp3   1.994269 -1.934466  0.612049  1.459568 -1.916059  3.988538
# sp4   1.106287 -0.586124  0.998881  0.862140 -1.735787  2.212574
# sp5   0.415147  0.152710  0.149481  0.148058 -0.506599  0.830293
# sp6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665 -0.294106
# sp7   0.011269 -0.483801 -1.129110  0.284472  0.095777  0.022539
# sp8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841 -0.275886
# sp9  -0.165580  0.068137 -0.367314  0.304182  1.241040 -0.331160

# %% [markdown]
# RENMAE COLUMN IN PANDAS DATAFRAME

# %%
my_dataframe
# Out:
#          first    second     third   column4    fourth   column6
# spin
# sp1   0.584527  1.426794 -0.229540 -1.608589  0.467805  1.169055
# sp2  -1.102857 -0.954725  0.626251  0.107779 -0.458245 -2.205715
# sp3   1.994269 -1.934466  0.612049  1.459568 -1.916059  3.988538
# sp4   1.106287 -0.586124  0.998881  0.862140 -1.735787  2.212574
# sp5   0.415147  0.152710  0.149481  0.148058 -0.506599  0.830293
# sp6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665 -0.294106
# sp7   0.011269 -0.483801 -1.129110  0.284472  0.095777  0.022539
# sp8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841 -0.275886
# sp9  -0.165580  0.068137 -0.367314  0.304182  1.241040 -0.331160

# %%
my_dataframe.rename(columns={'column1':'first',
                    'column2':'second',
                    'column3':'third',
                    'column5':'fourth',
                    'sixth':'fifth'},inplace =True) # renaming all the column

# %%
my_dataframe
# Out:
#          first    second     third   column4    fourth   column6
# spin
# sp1   0.584527  1.426794 -0.229540 -1.608589  0.467805  1.169055
# sp2  -1.102857 -0.954725  0.626251  0.107779 -0.458245 -2.205715
# sp3   1.994269 -1.934466  0.612049  1.459568 -1.916059  3.988538
# sp4   1.106287 -0.586124  0.998881  0.862140 -1.735787  2.212574
# sp5   0.415147  0.152710  0.149481  0.148058 -0.506599  0.830293
# sp6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665 -0.294106
# sp7   0.011269 -0.483801 -1.129110  0.284472  0.095777  0.022539
# sp8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841 -0.275886
# sp9  -0.165580  0.068137 -0.367314  0.304182  1.241040 -0.331160

# %%
my_dataframe.rename(columns={'first':1}) # renmae only 1 column name
# Out:
#              1    second     third   column4    fourth   column6
# spin
# sp1   0.584527  1.426794 -0.229540 -1.608589  0.467805  1.169055
# sp2  -1.102857 -0.954725  0.626251  0.107779 -0.458245 -2.205715
# sp3   1.994269 -1.934466  0.612049  1.459568 -1.916059  3.988538
# sp4   1.106287 -0.586124  0.998881  0.862140 -1.735787  2.212574
# sp5   0.415147  0.152710  0.149481  0.148058 -0.506599  0.830293
# sp6  -0.147053 -0.028043  0.341747 -1.958957 -1.318665 -0.294106
# sp7   0.011269 -0.483801 -1.129110  0.284472  0.095777  0.022539
# sp8  -0.137943  0.427747 -1.297815 -1.101616 -0.002841 -0.275886
# sp9  -0.165580  0.068137 -0.367314  0.304182  1.241040 -0.331160

# %% [markdown]
# TAIL COLUMN INDEX

# %%
data
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %%
data['make']
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 196          volvo
# 197          volvo
# 198          volvo
# 199          volvo
# 200          volvo
# Name: make, Length: 201, dtype: object

# %%
data.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=201, step=1)

# %% [markdown]
# ISNULL() OR ISNA()

# %%
data.isnull()
# Out:
#      symboling  normalized_losses   make  fuel_type  aspiration  \
# 0        False              False  False      False       False
# 1        False              False  False      False       False
# 2        False              False  False      False       False
# 3        False              False  False      False       False
# 4        False              False  False      False       False
# ..         ...                ...    ...        ...         ...
# 196      False              False  False      False       False
# 197      False              False  False      False       False
# 198      False              False  False      False       False
# 199      False              False  False      False       False
# 200      False              False  False      False       False
#
#      number_of_doors  body_style  drive_wheels  engine_location  wheel_base  \
# 0              False       False         False            False       False
# ...

# %%
data.isna()
# Out:
#      symboling  normalized_losses   make  fuel_type  aspiration  \
# 0        False              False  False      False       False
# 1        False              False  False      False       False
# 2        False              False  False      False       False
# 3        False              False  False      False       False
# 4        False              False  False      False       False
# ..         ...                ...    ...        ...         ...
# 196      False              False  False      False       False
# 197      False              False  False      False       False
# 198      False              False  False      False       False
# 199      False              False  False      False       False
# 200      False              False  False      False       False
#
#      number_of_doors  body_style  drive_wheels  engine_location  wheel_base  \
# 0              False       False         False            False       False
# ...

# %%
data.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# make                   0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %%
# data.dropna() # use dropna to drop anu NaN in the dataset

# %% [markdown]
# PANDAS DESCRIBE FUNCTION

# %%
data.describe() # gives the 5 number summary of the dataframe # works only on numeric data
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  201.000000         201.000000  201.000000  201.000000  201.000000
# mean     0.840796         125.189055   98.797015  174.200995   65.889055
# std      1.254802          33.572966    6.066366   12.322175    2.101471
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000         101.000000   94.500000  166.800000   64.100000
# 50%      1.000000         122.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.500000   66.600000
# max      3.000000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean    53.766667  2555.666667   126.875622    3.329701    3.261741
# std      2.447822   517.296727    41.546834    0.268166    0.317875
# ...

# %%
data.describe().T
# Out:
#                    count          mean          std      min      25%  \
# symboling          201.0      0.840796     1.254802    -2.00     0.00
# normalized_losses  201.0    125.189055    33.572966    65.00   101.00
# wheel_base         201.0     98.797015     6.066366    86.60    94.50
# length             201.0    174.200995    12.322175   141.10   166.80
# width              201.0     65.889055     2.101471    60.30    64.10
# height             201.0     53.766667     2.447822    47.80    52.00
# curb_weight        201.0   2555.666667   517.296727  1488.00  2169.00
# engine_size        201.0    126.875622    41.546834    61.00    98.00
# bore               201.0      3.329701     0.268166     2.54     3.15
# stroke             201.0      3.261741     0.317875     2.07     3.11
# compression_ratio  201.0     10.164279     4.004965     7.00     8.60
# horsepower         201.0    103.263682    37.389372    48.00    70.00
# ...

# %% [markdown]
# CONDITIONAL SELECTION

# %%
data.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 196    16845
# 197    19045
# 198    21485
# 199    22470
# 200    22625
# Name: price, Length: 201, dtype: int64

# %%
data['price'].max()
# Out:
# 45400

# %%
data[data['price']>40000]
# Out:
#     symboling  normalized_losses           make fuel_type aspiration  \
# 15          0                149            bmw       gas        std
# 70          0                140  mercedes-benz       gas        std
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 15             two      sedan          rwd           front       103.5  ...
# 70            four      sedan          rwd           front       120.9  ...
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 15          209         mpfi  3.62    3.39               8.0        182
# 70          308         mpfi  3.80    3.35               8.0        184
# 71          304         mpfi  3.80    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 15      5400       16           22  41315
# ...

# %%
data['price']>40000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# Name: price, Length: 201, dtype: bool

# %%
data[data['price']>20000][['make','price']]
# Out:
#               make  price
# 8             audi  23875
# 11             bmw  20970
# 12             bmw  21105
# 13             bmw  24565
# 14             bmw  30760
# 15             bmw  41315
# 16             bmw  36880
# 44          jaguar  32250
# 45          jaguar  35550
# 46          jaguar  36000
# 64   mercedes-benz  25552
# 65   mercedes-benz  28248
# 66   mercedes-benz  28176
# 67   mercedes-benz  31600
# 68   mercedes-benz  34184
# 69   mercedes-benz  35056
# 70   mercedes-benz  40960
# 71   mercedes-benz  45400
# 122        porsche  22018
# 123        porsche  32528
# 124        porsche  34028
# 125        porsche  37028
# 198          volvo  21485
# 199          volvo  22470
# 200          volvo  22625

# %%
data[(data['make'] == 'volvo') & (data['price']<50000)]
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 190         -2                103  volvo       gas        std            four
# 191         -1                 74  volvo       gas        std            four
# 192         -2                103  volvo       gas        std            four
# 193         -1                 74  volvo       gas        std            four
# 194         -2                103  volvo       gas      turbo            four
# 195         -1                 74  volvo       gas      turbo            four
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
# ...

# %%
data[(data['make'] == 'volvo') & (data['price']<50000)][['make','price']]
# Out:
#       make  price
# 190  volvo  12940
# 191  volvo  13415
# 192  volvo  15985
# 193  volvo  16515
# 194  volvo  18420
# 195  volvo  18950
# 196  volvo  16845
# 197  volvo  19045
# 198  volvo  21485
# 199  volvo  22470
# 200  volvo  22625

# %% [markdown]
# DEAL WITH NULL VALUES

# %%
df = pd.DataFrame({'value1':[100,np.nan,234,np.nan],
                  'value2':[300,121,np.nan,np.nan],
                  'value3':['XUI','VYU','NMA','IUY']})

# %%
df.head()
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 1     NaN   121.0    VYU
# 2   234.0     NaN    NMA
# 3     NaN     NaN    IUY

# %%
df.isnull()
# Out:
#    value1  value2  value3
# 0   False   False   False
# 1    True   False   False
# 2   False    True   False
# 3    True    True   False

# %%
df.isnull().sum()
# Out:
# value1    2
# value2    2
# value3    0
# dtype: int64

# %%
df.fillna(df.mean(),inplace=True) # filling with mean of each colun
# Out:
# <ipython-input-116-4c482d8f0f7a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(),inplace=True) # filling with mean of each colun

# %%
df.mean()
# Out:
# <ipython-input-117-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# value1    167.0
# value2    210.5
# dtype: float64

# %% [markdown]
# SORTING VALUES IN PANDAS

# %%
df.sort_values(by='value2',ascending=True)
# Out:
#    value1  value2 value3
# 1   167.0   121.0    VYU
# 2   234.0   210.5    NMA
# 3   167.0   210.5    IUY
# 0   100.0   300.0    XUI

# %%
df.sort_values(by='value2',ascending=False)
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 2   234.0   210.5    NMA
# 3   167.0   210.5    IUY
# 1   167.0   121.0    VYU

# %%
data.sort_values(by='price',ascending=False).head()
# Out:
#      symboling  normalized_losses           make fuel_type aspiration  \
# 71           1                140  mercedes-benz       gas        std
# 15           0                149            bmw       gas        std
# 70           0                140  mercedes-benz       gas        std
# 125          3                128        porsche       gas        std
# 16           0                149            bmw       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 71              two      hardtop          rwd           front       112.0
# 15              two        sedan          rwd           front       103.5
# 70             four        sedan          rwd           front       120.9
# 125             two  convertible          rwd            rear        89.5
# 16             four        sedan          rwd           front       110.0
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %% [markdown]
# GROUPBY

# %%
data.groupby('fuel_type').count()
# Out:
#            symboling  normalized_losses  make  aspiration  number_of_doors  \
# fuel_type
# diesel            20                 20    20          20               20
# gas              181                181   181         181              181
#
#            body_style  drive_wheels  engine_location  wheel_base  length  ...  \
# fuel_type                                                                 ...
# diesel             20            20               20          20      20  ...
# gas               181           181              181         181     181  ...
#
#            engine_size  fuel_system  bore  stroke  compression_ratio  \
# fuel_type
# diesel              20           20    20      20                 20
# gas                181          181   181     181                181
#
#            horsepower  peak_rpm  city_mpg  highway_mpg  price
# fuel_type
# diesel             20        20        20           20     20
# ...

# %% [markdown]
# COUNT() VALUE_COUNT()

# %%
data['make'].count() # counting how many items are in make column
# Out:
# 201

# %%
data['make'].value_counts() # counting each item in make column
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64

# %% [markdown]
# CONCATENATION FUNCTION

# %%
mm = {'one':[2,3,1,4,5],
      'two':[5,4,3,2,1],
      'three':['a','a','b','b','c']}

# %%
mm
# Out:
# {'one': [2, 3, 1, 4, 5],
#  'two': [5, 4, 3, 2, 1],
#  'three': ['a', 'a', 'b', 'b', 'c']}

# %%
mm1 = pd.DataFrame(mm)

# %%
mm1
# Out:
#    one  two three
# 0    2    5     a
# 1    3    4     a
# 2    1    3     b
# 3    4    2     b
# 4    5    1     c

# %%
df
# Out:
#    value1  value2 value3
# 0   100.0   300.0    XUI
# 1   167.0   121.0    VYU
# 2   234.0   210.5    NMA
# 3   167.0   210.5    IUY

# %%
new_df = pd.concat([df,mm1]) # use the concat() to put 2 dataframes together

# %%
new_df
# Out:
#    value1  value2 value3  one  two three
# 0   100.0   300.0    XUI  NaN  NaN   NaN
# 1   167.0   121.0    VYU  NaN  NaN   NaN
# 2   234.0   210.5    NMA  NaN  NaN   NaN
# 3   167.0   210.5    IUY  NaN  NaN   NaN
# 0     NaN     NaN    NaN  2.0  5.0     a
# 1     NaN     NaN    NaN  3.0  4.0     a
# 2     NaN     NaN    NaN  1.0  3.0     b
# 3     NaN     NaN    NaN  4.0  2.0     b
# 4     NaN     NaN    NaN  5.0  1.0     c

# %%
new_df = pd.concat([df,mm1],axis=1)

# %%
new_df
# Out:
#    value1  value2 value3  one  two three
# 0   100.0   300.0    XUI    2    5     a
# 1   167.0   121.0    VYU    3    4     a
# 2   234.0   210.5    NMA    1    3     b
# 3   167.0   210.5    IUY    4    2     b
# 4     NaN     NaN    NaN    5    1     c

# %% [markdown]
# CREATING DATASETS

# %%
sales = {'Jones':10000,
         'Chris':5000,
         'Piyush':440,
         'Meera':6700,
         'Rahul':300}
region = {'Jones':'West',
          'Chris':np.nan,
          'Piyush':'West',
          'Meera':np.nan,
          'Anthony':'East',
          'Ellen':'South',
          'Josh':'West',
          'Simran':'East',
          'Oscar':'North'}

# %%
sales_df = pd.DataFrame.from_dict(sales,orient='index',columns=['sales'])
region_df = pd.DataFrame.from_dict(region,orient='index',columns=['region'])

# %%
sales_df
# Out:
#         sales
# Jones   10000
# Chris    5000
# Piyush    440
# Meera    6700
# Rahul     300

# %%
region_df
# Out:
#         region
# Jones     West
# Chris      NaN
# Piyush    West
# Meera      NaN
# Anthony   East
# Ellen    South
# Josh      West
# Simran    East
# Oscar    North

# %% [markdown]
# JOIN

# %%
joined_df= region_df.join(sales_df,how='left')
print(joined_df)
# Out:
#         region    sales
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN

# %%
joined_df1= sales_df.join(region_df,how='right')
print(joined_df1)
# Out:
#            sales region
# Jones    10000.0   West
# Chris     5000.0    NaN
# Piyush     440.0   West
# Meera     6700.0    NaN
# Anthony      NaN   East
# Ellen        NaN  South
# Josh         NaN   West
# Simran       NaN   East
# Oscar        NaN  North

# %%
joined_df2= sales_df.join(region_df,how='left')
print(joined_df2)
# Out:
#         sales region
# Jones   10000   West
# Chris    5000    NaN
# Piyush    440   West
# Meera    6700    NaN
# Rahul     300    NaN

# %%
joined_df3= region_df.join(sales_df,how='right')
print(joined_df3)
# Out:
#        region  sales
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700
# Rahul     NaN    300

# %%
joined_df4= sales_df.join(region_df,how='inner')
print(joined_df4)
# Out:
#         sales region
# Jones   10000   West
# Chris    5000    NaN
# Piyush    440   West
# Meera    6700    NaN

# %%
joined_df5= sales_df.join(region_df,how='outer')
print(joined_df5)
# Out:
#            sales region
# Anthony      NaN   East
# Chris     5000.0    NaN
# Ellen        NaN  South
# Jones    10000.0   West
# Josh         NaN   West
# Meera     6700.0    NaN
# Oscar        NaN  North
# Piyush     440.0   West
# Rahul      300.0    NaN
# Simran       NaN   East

# %% [markdown]
# MERGE

# %%
region_df.index.name = 'names'
sales_df.index.name = 'names'

# %%
print(region_df)
print('-'*15)
print(sales_df)
# Out:
#         region
# names
# Jones     West
# Chris      NaN
# Piyush    West
# Meera      NaN
# Anthony   East
# Ellen    South
# Josh      West
# Simran    East
# Oscar    North
# ---------------
#         sales
# names
# Jones   10000
# Chris    5000
# Piyush    440
# Meera    6700
# Rahul     300

# %%
print(pd.merge(region_df,sales_df,on='names'))
# Out:
#        region  sales
# names
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
print(pd.merge(region_df,sales_df,on='names',how='left'))
# Out:
#         region    sales
# names
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN

# %%
print(pd.merge(region_df,sales_df,on='names',how='right'))
# Out:
#        region  sales
# names
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700
# Rahul     NaN    300

# %%
print(pd.merge(region_df,sales_df,on='names',how='inner'))
# Out:
#        region  sales
# names
# Jones    West  10000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
print(pd.merge(region_df,sales_df,on='names',how='outer'))
# Out:
#         region    sales
# names
# Jones     West  10000.0
# Chris      NaN   5000.0
# Piyush    West    440.0
# Meera      NaN   6700.0
# Anthony   East      NaN
# Ellen    South      NaN
# Josh      West      NaN
# Simran    East      NaN
# Oscar    North      NaN
# Rahul      NaN    300.0
